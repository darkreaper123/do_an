# %%
#compare with other baselines

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/do_an
# Out:
# /content/drive/MyDrive/do_an

# %%
#goat

# %%
# !python main_gift4rec_simple_kgat.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-4 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 0 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-3 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 1000 --n_iters_training_second_task_each_epoch 1 --folder_save_model GIFT4Rec_advanced_kgat_test --n_epoch 150 --use_weight_embeds_no_grad 0
# Out:
# 2023-09-09 16:24:48.706157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 16:24:49.649823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All logs will be saved to trained_model/GIFT4Rec_advanced_kgat_test/douban_one_task/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log0.log
# ...

# %%
#dropoutnet

# %%
# !python main_kgat_2_dropoutnet.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --folder_save_model 'KGAT_DropoutNet' --n_epoch 300
# Out:
# 2023-09-09 16:57:31.477923: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 16:57:32.460688: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All logs will be saved to trained_model/KGAT_DropoutNet/douban_one_task/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log1.log
# ...

# %%
#gift4rec

# %%
# !python main_gift4rec_advanced_kgat.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 1 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-3 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 3 --n_iters_training_second_task_each_epoch 1 --folder_save_model GIFT4Rec_advanced_kgat_test --n_epoch 150 --use_weight_embeds_no_grad 1
# Out:
# 2023-11-18 11:10:15.230175: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 11:10:15.230230: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 11:10:15.230270: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 11:10:15.242294: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#ablation study

# %%
#no gradient protecting between two tasks

# %%
# !python main_gift4rec_simple_kgat.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-4 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 1 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-3 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 1000 --n_iters_training_second_task_each_epoch 1 --folder_save_model GIFT4Rec_advanced_kgat_test --n_epoch 150 --use_weight_embeds_no_grad 1
# Out:
# 2023-09-09 17:33:42.883057: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 17:33:43.865822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All logs will be saved to trained_model/GIFT4Rec_advanced_kgat_test/douban_one_task/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log2.log
# ...

# %%
#no global loss

# %%
# !python main_gift4rec_simple_kgat.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-4 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 0 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-3 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 1000 --n_iters_training_second_task_each_epoch 1 --folder_save_model GIFT4Rec_advanced_kgat_test --n_epoch 150 --use_weight_embeds_no_grad 1
# Out:
# 2023-09-09 18:21:46.267636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 18:21:47.231075: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All logs will be saved to trained_model/GIFT4Rec_advanced_kgat_test/douban_one_task/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log4.log
# ...

# %%
#no seperated training

# %%
# !python main_gift4rec_advanced_kgat.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 1 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-3 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 3 --n_iters_training_second_task_each_epoch 1 --folder_save_model GIFT4Rec_advanced_kgat_test --n_epoch 150 --use_weight_embeds_no_grad 0
# Out:
# 2023-11-18 10:33:28.699005: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 10:33:28.699066: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 10:33:28.699107: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 10:33:28.711938: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#

# %%
# !python main_kgat_2_raw_new_ver.py --data_name douban_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024 --kg_batch_size 2048 --lr 1e-3 --masking_train 1 --stopping_steps 20 --folder_save_model KGAT_RAW_DOUBAN_ONE_TASK --train_kg 0 --n_epoch 1000
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Evaluating Iteration: 100% 1/1 [00:00<00:00,  6.76it/s]
# 2023-12-05 18:58:47,887 - root - INFO - CF Evaluation (Cold - start): Epoch 0445 | Total Time 0.2s | Precision [0.0013, 0.0015], Recall [0.0015, 0.0036], NDCG [0.0012, 0.0023]
# 2023-12-05 18:58:47,887 - root - INFO - Averaged CF Evaluation: Epoch 0445 | Total Time 0.0s | Precision [0.0012, 0.0013], Recall [0.0126, 0.0301], NDCG [0.0045, 0.0083]
# 2023-12-05 18:58:50,243 - root - INFO - CF Training: Epoch 0446 Total Iter 0010 | Total Time 2.4s | Iter Mean Loss 0.2749
# 2023-12-05 18:58:50,244 - root - INFO - KG Training: Epoch 0446 Total Iter 0010 | Total Time 0.0s | Iter Mean Loss 0.0000
# 2023-12-05 18:58:51,543 - root - INFO - Update Attention: Epoch 0446 | Total Time 1.3s
# 2023-12-05 18:58:51,544 - root - INFO - CF + KG Training: Epoch 0446 | Total Time 3.7s
# Evaluating Iteration: 100% 1/1 [00:01<00:00,  1.39s/it]
# ...
