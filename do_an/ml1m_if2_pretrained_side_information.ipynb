# %%
# !python main_if2_pretrained_side_information.py --data_name ml_1m_one_task --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --use_weight_embeds 1 --training_embed_weight 1 --use_train_data_to_train_weight_embed 0 --stopping_steps 20 --train_weight_embed_lr 1e-5 --use_binary_weight 0 --training_embed_weight_batch_size 200 --stop_training_embed_weight_epoch 1000 --n_iters_training_second_task_each_epoch 1 --folder_save_model IF2_pretrained_side_information --n_epoch 1000 --use_weight_embeds_no_grad 0
# Out:
# All logs will be saved to trained_model/IF2_pretrained_side_information/ml_1m_one_task/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log3.log
# cuda:0
# None
# Max id user : 5435
# Max id item : 3952
# [43, 0]
# Item category feature is not existed
# Item category feature is not existed
# No items features
# 1
# 2
# 3
# 4
# [5435, 3952]
# 0
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# ...
