# %%
import numpy as np
np.fromfile("recsys2017.pub/eval/trained/warm/U.csv.bin", dtype=np.float32).reshape(-1, 200).shape
# Out:
# (1497021, 200)

# %%
from sklearn import datasets
datasets.load_svmlight_file("recsys2017.pub/eval/user_features_0based.txt", zero_based=True, dtype=np.float32)
# Out:
# (<1497021x831 sparse matrix of type '<class 'numpy.float32'>'
#  	with 16806412 stored elements in Compressed Sparse Row format>,
#  array([0.000000e+00, 1.000000e+00, 2.000000e+00, ..., 1.497018e+06,
#         1.497019e+06, 1.497020e+06]))
